# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import mpl_toolkits
import numpy as np
# %matplotlib inline
# Out:
# /Users/tonyktan/Desktop/GA/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
sample_sub = pd.read_csv('sample_submission.csv')
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')

# %%
sample_sub.head()
# Out:
#    QuoteNumber  QuoteConversion_Flag
# 0            3                     0
# 1            5                     0
# 2            7                     0
# 3            9                     0
# 4           10                     0

# %%
sample_sub.count()
# Out:
# QuoteNumber             173836
# QuoteConversion_Flag    173836
# dtype: int64

# %%
test.head()
# Out:
#    QuoteNumber Original_Quote_Date Field6  Field7  Field8  Field9 Field10  \
# 0            3          2014-08-12      E      16  0.9364  0.0006   1,487
# 1            5          2013-09-07      F      11  0.9919  0.0038     564
# 2            7          2013-03-29      F      15  0.8945  0.0038     564
# 3            9          2015-03-21      K      21  0.8870  0.0004   1,113
# 4           10          2014-12-10      B      25  0.9153  0.0007     935
#
#    Field11 Field12  CoverageField1A        ...          GeographicField59A  \
# 0   1.3045       N                4        ...                           1
# 1   1.1886       N                8        ...                          10
# 2   1.0670       N               11        ...                          10
# 3   1.2665       Y               14        ...                           8
# 4   1.0200       N                4        ...                           7
#
#    GeographicField59B  GeographicField60A  GeographicField60B  \
# 0                   1                  -1                   1
# 1                  10                  -1                   5
# 2                  11                  -1                  20
# 3                   8                  -1                  13
# 4                   7                  -1                   3
#
#    GeographicField61A  GeographicField61B  GeographicField62A  \
# 0                  -1                  20                  -1
# 1                  -1                   5                  -1
# 2                  -1                  22                  -1
# 3                  -1                   8                  -1
# 4                  -1                  22                  -1
#
#    GeographicField62B  GeographicField63  GeographicField64
# 0                  25                  Y                 IL
# 1                  21                  N                 NJ
# 2                  11                  N                 NJ
# 3                  21                  N                 TX
# 4                  21                  N                 CA
#
# [5 rows x 298 columns]

# %%
test.count()
# Out:
# QuoteNumber            173836
# Original_Quote_Date    173836
# Field6                 173836
# Field7                 173836
# Field8                 173836
# Field9                 173836
# Field10                173836
# Field11                173836
# Field12                173836
# CoverageField1A        173836
# CoverageField1B        173836
# CoverageField2A        173836
# CoverageField2B        173836
# CoverageField3A        173836
# CoverageField3B        173836
# CoverageField4A        173836
# CoverageField4B        173836
# CoverageField5A        173836
# CoverageField5B        173836
# CoverageField6A        173836
# CoverageField6B        173836
# CoverageField8         173836
# CoverageField9         173836
# CoverageField11A       173836
# CoverageField11B       173836
# SalesField1A           173836
# SalesField1B           173836
# SalesField2A           173836
# SalesField2B           173836
# SalesField3            173836
#                         ...
# GeographicField49A     173836
# GeographicField49B     173836
# GeographicField50A     173836
# GeographicField50B     173836
# GeographicField51A     173836
# GeographicField51B     173836
# GeographicField52A     173836
# GeographicField52B     173836
# GeographicField53A     173836
# GeographicField53B     173836
# GeographicField54A     173836
# GeographicField54B     173836
# GeographicField55A     173836
# GeographicField55B     173836
# GeographicField56A     173836
# GeographicField56B     173836
# GeographicField57A     173836
# GeographicField57B     173836
# GeographicField58A     173836
# GeographicField58B     173836
# GeographicField59A     173836
# GeographicField59B     173836
# GeographicField60A     173836
# GeographicField60B     173836
# GeographicField61A     173836
# GeographicField61B     173836
# GeographicField62A     173836
# GeographicField62B     173836
# GeographicField63      173836
# GeographicField64      173836
# dtype: int64

# %%
train.head()
# Out:
#    QuoteNumber Original_Quote_Date  QuoteConversion_Flag Field6  Field7  \
# 0            1          2013-08-16                     0      B      23
# 1            2          2014-04-22                     0      F       7
# 2            4          2014-08-25                     0      F       7
# 3            6          2013-04-15                     0      J      10
# 4            8          2014-01-25                     0      E      23
#
#    Field8  Field9 Field10  Field11 Field12        ...          \
# 0  0.9403  0.0006     965   1.0200       N        ...
# 1  1.0006  0.0040     548   1.2433       N        ...
# 2  1.0006  0.0040     548   1.2433       N        ...
# 3  0.9769  0.0004   1,165   1.2665       N        ...
# 4  0.9472  0.0006   1,487   1.3045       N        ...
#
#    GeographicField59A  GeographicField59B  GeographicField60A  \
# 0                   9                   9                  -1
# 1                  10                  10                  -1
# 2                  15                  18                  -1
# 3                   6                   5                  -1
# 4                  18                  22                  -1
#
#    GeographicField60B  GeographicField61A  GeographicField61B  \
# 0                   8                  -1                  18
# 1                  11                  -1                  17
# 2                  21                  -1                  11
# 3                  10                  -1                   9
# 4                  10                  -1                  11
#
#    GeographicField62A  GeographicField62B  GeographicField63  \
# 0                  -1                  10                  N
# 1                  -1                  20                  N
# 2                  -1                   8                  N
# 3                  -1                  21                  N
# 4                  -1                  12                  N
#
#    GeographicField64
# 0                 CA
# 1                 NJ
# 2                 NJ
# 3                 TX
# 4                 IL
#
# [5 rows x 299 columns]

# %%
train.count()
# Out:
# QuoteNumber             260753
# Original_Quote_Date     260753
# QuoteConversion_Flag    260753
# Field6                  260753
# Field7                  260753
# Field8                  260753
# Field9                  260753
# Field10                 260753
# Field11                 260753
# Field12                 260753
# CoverageField1A         260753
# CoverageField1B         260753
# CoverageField2A         260753
# CoverageField2B         260753
# CoverageField3A         260753
# CoverageField3B         260753
# CoverageField4A         260753
# CoverageField4B         260753
# CoverageField5A         260753
# CoverageField5B         260753
# CoverageField6A         260753
# CoverageField6B         260753
# CoverageField8          260753
# CoverageField9          260753
# CoverageField11A        260753
# CoverageField11B        260753
# SalesField1A            260753
# SalesField1B            260753
# SalesField2A            260753
# SalesField2B            260753
#                          ...
# GeographicField49A      260753
# GeographicField49B      260753
# GeographicField50A      260753
# GeographicField50B      260753
# GeographicField51A      260753
# GeographicField51B      260753
# GeographicField52A      260753
# GeographicField52B      260753
# GeographicField53A      260753
# GeographicField53B      260753
# GeographicField54A      260753
# GeographicField54B      260753
# GeographicField55A      260753
# GeographicField55B      260753
# GeographicField56A      260753
# GeographicField56B      260753
# GeographicField57A      260753
# GeographicField57B      260753
# GeographicField58A      260753
# GeographicField58B      260753
# GeographicField59A      260753
# GeographicField59B      260753
# GeographicField60A      260753
# GeographicField60B      260753
# GeographicField61A      260753
# GeographicField61B      260753
# GeographicField62A      260753
# GeographicField62B      260753
# GeographicField63       260753
# GeographicField64       260753
# dtype: int64

# %%
sns.heatmap(train.cov())
